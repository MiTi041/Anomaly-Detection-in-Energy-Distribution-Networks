# %% [markdown]
# # Präsentation - Analyse eines Energieverteilungsnetzwerkes

# %% [markdown]
# ##### Initialisierung

# %%
# %load_ext autoreload
# %autoreload 2

import src.config
from src.data_loader import get_balance_data, get_interchange_data, get_subregion_data
import plotly.express as px
import polars as pl

df_balance = get_balance_data()
df_interchange = get_interchange_data()
df_subregion = get_subregion_data()

# %% [markdown]
# #### Problem & Motivation
# - Komplexität von Stromnetzen
# - Risiko von Teilnetzausfällen
# - Ziel: Anomalien früh erkennen

# %% [markdown]
# #### Data Source & Data Understanding
# - Quelle (EIA Grid Data)
# - Datentyp: Zeitreihen
# - Features: z. B. Load, Frequency, Region
#
# Optional: kleine Grafik der Datenstruktur.

# %% [markdown]
# #### Methods
# Welche Verfahren hast du verwendet?
#
# Beispiel:
# - Isolation Forest
# - One-Class SVM
#
# Kurze Erklärung, kein Mathe-Beweis.

# %% [markdown]
# #### Results
# Visualisierung:
# - Zeitreihe mit markierten Anomalien
# - Vergleich der Modelle
